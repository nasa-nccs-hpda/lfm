# %%
# Notebook imports
# Generated from standard/third-party imports used throughout this notebook.
import json
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
from pathlib import Path

# %% [markdown]
# # General Scratch
#
# This notebook is reserved for exploratory work that is not specific to a single dataset. Dataset-specific scratch work has been split into separate notebooks:
#
# - `scratch_imp.ipynb` for IMP dataset exploration.
# - `scratch_nac.ipynb` for NAC dataset exploration.
# - `scratch_wac.ipynb` for WAC dataset exploration.
